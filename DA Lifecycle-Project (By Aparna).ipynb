# %% [markdown]
# ## “House Prices Dataset”
# ##### https://www.kaggle.com/datasets/anishaguptaaaaa/house-prices/data?select=train.csv

# %% [markdown]
# ## Business Understanding
# #### “Understand the factors affecting house prices and identify the key drivers influencing price variation.”

# %% [markdown]
# ## Problem Statement:
# #### “Identify the key factors that influence house prices and analyze the relationship between features such as area, number of bedrooms, and location.”

# %% [markdown]
# ## Data Collection

# %%
import pandas as pd  #for data handling and analysis

# %%
df = pd.read_csv("train.csv") # Load dataset from csv file into dataframe
df #displays the dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head(10)  # Display first 10 rows of the dataset
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df.tail(10) #Display last 10 rows of the dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %% [markdown]
# ### Data Cleaning

# %%
df.isnull().sum() # Checks and counts missing (null) values in each column
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.columns  # Displays all column names in the dataset
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df=df.drop(["Alley","PoolQC","Fence","MiscFeature"],axis=1,errors='ignore')
# drop(): removes columns
# axis=1: column-wise operation
# errors='ignore': avoids error if column is not present

# %%
df['LotFrontage'].fillna(df['LotFrontage'].median(),inplace=True)
# fillna(): fills missing values
# median(): middle value (used for numerical data)
# Fills missing values in LotFrontage column using the median value

df['GarageYrBlt'].fillna(0,inplace=True)  #0: used when value is not available
# Fills missing values in GarageYrBlt column with 0
# Out:
# C:\Users\aparn\AppData\Local\Temp\ipykernel_13528\3492171245.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LotFrontage'].fillna(df['LotFrontage'].median(),inplace=True)
# C:\Users\aparn\AppData\Local\Temp\ipykernel_13528\3492171245.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df=pd.get_dummies(df, drop_first=True) # Convert categorical to numerical
# get_dummies(): converts text data into numbers
# drop_first=True: removes one category to avoid duplicate columns

# %%
df.dtypes #check data types
# Out:
# Id                         int64
# MSSubClass                 int64
# LotFrontage              float64
# LotArea                    int64
# OverallQual                int64
#                           ...
# SaleCondition_AdjLand       bool
# SaleCondition_Alloca        bool
# SaleCondition_Family        bool
# SaleCondition_Normal        bool
# SaleCondition_Partial       bool
# Length: 237, dtype: object

# %%
X=df.drop('SalePrice',axis=1) # Creates feature variables by removing the target column (SalePrice)
X
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# ...

# %%
y=df['SalePrice'] # Stores the target variable (SalePrice) separately 
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Univariate Analysis

# %%
df['SalePrice'].describe() #Non visualization
#describe(): gives summary statistics
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
import matplotlib.pyplot as plt # for plotting graphs

plt.hist(df['SalePrice']) # Creates a histogram to show distribution of SalePrice
plt.title("Distribution of Sale Price") # Adds title to the graph
plt.show()  # Displays the graph             #Visualization

# %% [markdown]
# ### Bivariate Analysis

# %%
df[['SalePrice','GrLivArea']].corr()  #Non visualization
# Calculates correlation between SalePrice and GrLivArea
#corr(): shows relationship between variables

#+1: strong positive relationship (increase to increase)
#0: no relationship
#-1: strong negative relationship (increase to decrease)
# Out:
#            SalePrice  GrLivArea
# SalePrice   1.000000   0.708624
# GrLivArea   0.708624   1.000000

# %%
plt.scatter(df['GrLivArea'],df['SalePrice']) # Creates a scatter plot between Living Area and Sale Price
plt.xlabel("Living Area") # Labels X-axis (independent variable)
plt.ylabel("Sale Price") # Labels Y-axis (dependent variable)
plt.title("Area vs Price")  # Adds title to the graph
plt.show()   # Displays the graph     #Visualization

# %% [markdown]
# ### Multivariate Analysis

# %%
df.corr() #Non visualization
# Calculates correlation between all numerical columns in the dataset
# Out:
#                              Id  MSSubClass  LotFrontage   LotArea  \
# Id                     1.000000    0.011156    -0.009921 -0.033226
# MSSubClass             0.011156    1.000000    -0.356718 -0.139781
# LotFrontage           -0.009921   -0.356718     1.000000  0.304522
# LotArea               -0.033226   -0.139781     0.304522  1.000000
# OverallQual           -0.028365    0.032628     0.234812  0.105806
# ...                         ...         ...          ...       ...
# SaleCondition_AdjLand -0.034852    0.016241    -0.036570 -0.013208
# SaleCondition_Alloca  -0.009018    0.030002    -0.018040  0.008966
# SaleCondition_Family   0.004865    0.000983     0.016250 -0.010781
# SaleCondition_Normal   0.015881    0.024359    -0.074146  0.005711
# SaleCondition_Partial -0.020738   -0.051068     0.127293  0.022635
#
#                        OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id                       -0.028365     0.012609  -0.012713     -0.021998
# ...

# %%
import seaborn as sns #for advanced visualizations

corr = df.corr() # Calculates correlation between all numerical columns

top_corr = corr['SalePrice'].abs().sort_values(ascending=False).head(15)
# Selects top 15 features most correlated with SalePrice
# abs(): Converts values to positive
# sort_values: Sorts correlation from highest to lowest

corr_matrix = df[top_corr.index].corr() #Creates a smaller correlation matrix using selected columns

plt.figure(figsize=(12,10)) # Sets the size of the figure
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm') #Creates heatmap with correlation values displayed
plt.title("Correlation Heatmap") # Adds title to the graph
plt.show() # Displays the heatmap   #Visualization

# %%
sns.pairplot(df[['SalePrice','GrLivArea','OverallQual','GarageArea']])
plt.show() # Creates pairwise scatter plots to show relationships between multiple variables

# %% [markdown]
# ## Observations/ Insights

# %% [markdown]
# 1. Living Area (GrLivArea) has strong positive correlation with SalePrice
# 2. Overall Quality (OverallQual) significantly impact on house price
# 3. Some features have very weak correlation with SalePrice and can be removed for better analysis.
